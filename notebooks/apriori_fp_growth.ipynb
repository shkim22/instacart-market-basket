# %%
from neo4j import GraphDatabase
import getpass
import pandas as pd
import numpy as np
from itertools import combinations
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %%
uri = "bolt://localhost:7687"
username = "neo4j"
password = getpass.getpass("Enter your Neo4j password: ")

driver = GraphDatabase.driver(uri, auth=(username, password))

def execute_query(driver, query):
    with driver.session() as session:
        result = session.run(query)
        return [record for record in result]

# get ALL nodes and edges WHERE eval_set <> "test"

query_order_nodes = """
MATCH (o:Order)
WHERE o.eval_set <> 'test'
RETURN id(o) as node_id, labels(o) as labels, properties(o) as properties
"""


order_nodes = execute_query(driver, query_order_nodes)

query_product_nodes = """
MATCH (p:Product)
RETURN id(p) as node_id, labels(p) as labels, properties(p) as properties
"""

product_nodes = execute_query(driver, query_product_nodes)


query_edges =   """
                MATCH (o:Order)-[r:ORDERED]->(p:Product)
                WHERE o.eval_set <> 'test'
                RETURN id(o) as start_node, id(p) as end_node, properties(r) as properties
                """

edges = execute_query(driver, query_edges)

driver.close()

# %% [markdown]
# # Product association rules
#
# ## A-priori Algorithm
#
# I did not implement from scratch as I did not think we needed to

# %%
product_id_mapping = {product['node_id']: product['properties']['product_name'] for product in product_nodes}
order_id_mapping = {order['node_id']: order['properties']['order_id'] for order in order_nodes}

transactions_dict = {}

for edge in edges:
    order_id = order_id_mapping[edge['start_node']]
    product_name = product_id_mapping[edge['end_node']]
    
    if order_id not in transactions_dict.keys():
        transactions_dict[order_id] = []
    
    transactions_dict[order_id].append(product_name)


transactions = list(transactions_dict.values())
for transaction in transactions:
    transaction.sort()

# %%
transactions[:3]
# Out:
# [['Creamy Almond Butter',
#   'Organic String Cheese',
#   'Original Beef Jerky',
#   'Pistachios',
#   'Soda'],
#  ['Bag of Organic Bananas',
#   'Bartlett Pears',
#   'Honeycrisp Apples',
#   'Organic Fuji Apples',
#   'Organic String Cheese',
#   'Original Beef Jerky',
#   'Pistachios',
#   'Soda'],
#  ['Cinnamon Toast Crunch',
#   'Organic String Cheese',
#   'Original Beef Jerky',
#   'Pistachios',
#   'Soda']]

# %%
# Just to confirm that there are many empty orders

orders_with_products = {edge['start_node'] for edge in edges}
orders_without_products = set(order_id_mapping.keys()) - orders_with_products

print(f"Number of orders: {len(order_id_mapping)}")
print(f"Number of orders with products: {len(orders_with_products)}")
print(f"Number of orders without products: {len(orders_without_products)}")
# Out:
# Number of orders: 3346083
# Number of orders with products: 1279158
# Number of orders without products: 2066925

# %%
# Initialize TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

df.head()
# Out:
#    #2 Coffee Filters  #2 Cone White Coffee Filters  #2 Mechanical Pencils  \
# 0              False                         False                  False
# 1              False                         False                  False
# 2              False                         False                  False
# 3              False                         False                  False
# 4              False                         False                  False
#
#    #4 Natural Brown Coffee Filters  & Go! Hazelnut Spread + Pretzel Sticks  \
# 0                            False                                   False
# 1                            False                                   False
# 2                            False                                   False
# 3                            False                                   False
# 4                            False                                   False
#
#    'Swingtop' Premium Lager  (70% Juice!) Mountain Raspberry Juice Squeeze  \
# 0                     False                                          False
# 1                     False                                          False
# 2                     False                                          False
# 3                     False                                          False
# 4                     False                                          False
#
#    +Energy Black Cherry Vegetable & Fruit Juice  .5\" Waterproof Tape  \
# 0                                         False                 False
# 1                                         False                 False
# 2                                         False                 False
# 3                                         False                 False
# 4                                         False                 False
#
#    0 Calorie Acai Raspberry Water Beverage  ...  \
# 0                                    False  ...
# 1                                    False  ...
# 2                                    False  ...
# 3                                    False  ...
# 4                                    False  ...
#
#    with Twist Ties Sandwich & Storage Bags  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    with Xylitol Cinnamon 18 Sticks Sugar Free Gum  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    with Xylitol Island Berry Lime 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Minty Sweet Twist 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Original Flavor 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Unwrapped Original Flavor 50 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Unwrapped Spearmint 50 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Watermelon Twist 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with a Splash of Mango Coconut Water  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    with a Splash of Pineapple Coconut Water
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
# [5 rows x 49111 columns]

# %%
# Adjust the min_support 
min_support_threshold = 0.01
frequent_itemsets = apriori(df, min_support=min_support_threshold, use_colnames=True)

# Adjust the min_threshold 
min_confidence_threshold = 0.04
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence_threshold)

# %%
rules
# Out:
#                  antecedents               consequents  antecedent support  \
# 0   (Bag of Organic Bananas)    (Organic Baby Spinach)            0.118126
# 1     (Organic Baby Spinach)  (Bag of Organic Bananas)            0.074927
# 2   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.118126
# 3     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.065256
# 4      (Organic Raspberries)  (Bag of Organic Bananas)            0.042407
# 5   (Bag of Organic Bananas)     (Organic Raspberries)            0.118126
# 6   (Bag of Organic Bananas)    (Organic Strawberries)            0.118126
# 7     (Organic Strawberries)  (Bag of Organic Bananas)            0.082734
# 8              (Large Lemon)                  (Banana)            0.048882
# 9                   (Banana)             (Large Lemon)            0.146920
# 10                  (Banana)         (Organic Avocado)            0.146920
# 11         (Organic Avocado)                  (Banana)            0.054849
# 12                  (Banana)    (Organic Baby Spinach)            0.146920
# 13    (Organic Baby Spinach)                  (Banana)            0.074927
# 14      (Organic Fuji Apple)                  (Banana)            0.027654
# 15                  (Banana)      (Organic Fuji Apple)            0.146920
# 16                  (Banana)    (Organic Strawberries)            0.146920
# 17    (Organic Strawberries)                  (Banana)            0.082734
# 18                  (Banana)            (Strawberries)            0.146920
# 19            (Strawberries)                  (Banana)            0.044812
# 20    (Organic Baby Spinach)    (Organic Hass Avocado)            0.074927
# 21    (Organic Hass Avocado)    (Organic Baby Spinach)            0.065256
# 22    (Organic Strawberries)    (Organic Baby Spinach)            0.082734
# 23    (Organic Baby Spinach)    (Organic Strawberries)            0.074927
# 24    (Organic Strawberries)    (Organic Hass Avocado)            0.082734
# 25    (Organic Hass Avocado)    (Organic Strawberries)            0.065256
# 26     (Organic Raspberries)    (Organic Strawberries)            0.042407
# 27    (Organic Strawberries)     (Organic Raspberries)            0.082734
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.074927  0.015717    0.133049  1.775708  0.006866    1.067042
# 1             0.118126  0.015717    0.209758  1.775708  0.006866    1.115953
# 2             0.065256  0.019182    0.162387  2.488453  0.011474    1.115961
# 3             0.118126  0.019182    0.293951  2.488453  0.011474    1.249027
# 4             0.118126  0.012622    0.297650  2.519760  0.007613    1.255604
# 5             0.042407  0.012622    0.106855  2.519760  0.007613    1.072159
# 6             0.082734  0.019693    0.166709  2.014992  0.009920    1.100774
# 7             0.118126  0.019693    0.238023  2.014992  0.009920    1.157350
# 8             0.146920  0.013071    0.267400  1.820038  0.005889    1.164456
# 9             0.048882  0.013071    0.088967  1.820038  0.005889    1.044000
# 10            0.054849  0.016487    0.112215  2.045904  0.008428    1.064617
# 11            0.146920  0.016487    0.300584  2.045904  0.008428    1.219704
# 12            0.074927  0.015904    0.108251  1.444742  0.004896    1.037369
# 13            0.146920  0.015904    0.212262  1.444742  0.004896    1.082948
# 14            0.146920  0.010385    0.375530  2.556016  0.006322    1.366086
# 15            0.027654  0.010385    0.070684  2.556016  0.006322    1.046303
# 16            0.082734  0.017375    0.118260  1.429394  0.005219    1.040290
# 17            0.146920  0.017375    0.210007  1.429394  0.005219    1.079857
# 18            0.044812  0.013080    0.089026  1.986676  0.006496    1.048535
# 19            0.146920  0.013080    0.291883  1.986676  0.006496    1.204715
# 20            0.065256  0.010616    0.141678  2.171106  0.005726    1.089036
# 21            0.074927  0.010616    0.162675  2.171106  0.005726    1.104796
# 22            0.074927  0.011850    0.143230  1.911580  0.005651    1.079721
# 23            0.082734  0.011850    0.158153  1.911580  0.005651    1.089587
# 24            0.065256  0.012555    0.151753  2.325492  0.007156    1.101971
# 25            0.082734  0.012555    0.192398  2.325492  0.007156    1.135789
# 26            0.082734  0.010759    0.253701  3.066460  0.007250    1.229086
# 27            0.042407  0.010759    0.130039  3.066460  0.007250    1.100731
#
#     zhangs_metric
# 0        0.495359
# 1        0.472227
# 2        0.678265
# 3        0.639901
# 4        0.629847
# 5        0.683926
# 6        0.571193
# 7        0.549154
# 8        0.473717
# 9        0.528158
# 10       0.599262
# 11       0.540885
# 12       0.360851
# 13       0.332768
# 14       0.626080
# 15       0.713610
# 16       0.352139
# 17       0.327498
# 18       0.582181
# 19       0.519946
# 20       0.583095
# 21       0.577062
# 22       0.519885
# 23       0.515497
# 24       0.621394
# 25       0.609775
# 26       0.703734
# 27       0.734674

# %%
filtered_frequent_itemsets = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x) >= 2)]

filtered_frequent_itemsets
# Out:
#       support                                        itemsets
# 103  0.015717  (Bag of Organic Bananas, Organic Baby Spinach)
# 104  0.019182  (Bag of Organic Bananas, Organic Hass Avocado)
# 105  0.012622   (Organic Raspberries, Bag of Organic Bananas)
# 106  0.019693  (Bag of Organic Bananas, Organic Strawberries)
# 107  0.013071                           (Large Lemon, Banana)
# 108  0.016487                       (Banana, Organic Avocado)
# 109  0.015904                  (Banana, Organic Baby Spinach)
# 110  0.010385                    (Organic Fuji Apple, Banana)
# 111  0.017375                  (Banana, Organic Strawberries)
# 112  0.013080                          (Banana, Strawberries)
# 113  0.010616    (Organic Baby Spinach, Organic Hass Avocado)
# 114  0.011850    (Organic Strawberries, Organic Baby Spinach)
# 115  0.012555    (Organic Strawberries, Organic Hass Avocado)
# 116  0.010759     (Organic Raspberries, Organic Strawberries)

# %% [markdown]
# ## FP growth Algorithm
#
# I did not implement from scratch here either

# %%
frequent_itemsets = fpgrowth(df, min_support=min_support_threshold, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence_threshold)
rules
# Out:
#                  antecedents               consequents  antecedent support  \
# 0   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.118126
# 1     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.065256
# 2     (Organic Strawberries)    (Organic Hass Avocado)            0.082734
# 3     (Organic Hass Avocado)    (Organic Strawberries)            0.065256
# 4     (Organic Baby Spinach)    (Organic Hass Avocado)            0.074927
# 5     (Organic Hass Avocado)    (Organic Baby Spinach)            0.065256
# 6      (Organic Raspberries)  (Bag of Organic Bananas)            0.042407
# 7   (Bag of Organic Bananas)     (Organic Raspberries)            0.118126
# 8      (Organic Raspberries)    (Organic Strawberries)            0.042407
# 9     (Organic Strawberries)     (Organic Raspberries)            0.082734
# 10                  (Banana)    (Organic Strawberries)            0.146920
# 11    (Organic Strawberries)                  (Banana)            0.082734
# 12  (Bag of Organic Bananas)    (Organic Strawberries)            0.118126
# 13    (Organic Strawberries)  (Bag of Organic Bananas)            0.082734
# 14    (Organic Strawberries)    (Organic Baby Spinach)            0.082734
# 15    (Organic Baby Spinach)    (Organic Strawberries)            0.074927
# 16                  (Banana)    (Organic Baby Spinach)            0.146920
# 17    (Organic Baby Spinach)                  (Banana)            0.074927
# 18  (Bag of Organic Bananas)    (Organic Baby Spinach)            0.118126
# 19    (Organic Baby Spinach)  (Bag of Organic Bananas)            0.074927
# 20                  (Banana)         (Organic Avocado)            0.146920
# 21         (Organic Avocado)                  (Banana)            0.054849
# 22                  (Banana)            (Strawberries)            0.146920
# 23            (Strawberries)                  (Banana)            0.044812
# 24      (Organic Fuji Apple)                  (Banana)            0.027654
# 25                  (Banana)      (Organic Fuji Apple)            0.146920
# 26             (Large Lemon)                  (Banana)            0.048882
# 27                  (Banana)             (Large Lemon)            0.146920
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.065256  0.019182    0.162387  2.488453  0.011474    1.115961
# 1             0.118126  0.019182    0.293951  2.488453  0.011474    1.249027
# 2             0.065256  0.012555    0.151753  2.325492  0.007156    1.101971
# 3             0.082734  0.012555    0.192398  2.325492  0.007156    1.135789
# 4             0.065256  0.010616    0.141678  2.171106  0.005726    1.089036
# 5             0.074927  0.010616    0.162675  2.171106  0.005726    1.104796
# 6             0.118126  0.012622    0.297650  2.519760  0.007613    1.255604
# 7             0.042407  0.012622    0.106855  2.519760  0.007613    1.072159
# 8             0.082734  0.010759    0.253701  3.066460  0.007250    1.229086
# 9             0.042407  0.010759    0.130039  3.066460  0.007250    1.100731
# 10            0.082734  0.017375    0.118260  1.429394  0.005219    1.040290
# 11            0.146920  0.017375    0.210007  1.429394  0.005219    1.079857
# 12            0.082734  0.019693    0.166709  2.014992  0.009920    1.100774
# 13            0.118126  0.019693    0.238023  2.014992  0.009920    1.157350
# 14            0.074927  0.011850    0.143230  1.911580  0.005651    1.079721
# 15            0.082734  0.011850    0.158153  1.911580  0.005651    1.089587
# 16            0.074927  0.015904    0.108251  1.444742  0.004896    1.037369
# 17            0.146920  0.015904    0.212262  1.444742  0.004896    1.082948
# 18            0.074927  0.015717    0.133049  1.775708  0.006866    1.067042
# 19            0.118126  0.015717    0.209758  1.775708  0.006866    1.115953
# 20            0.054849  0.016487    0.112215  2.045904  0.008428    1.064617
# 21            0.146920  0.016487    0.300584  2.045904  0.008428    1.219704
# 22            0.044812  0.013080    0.089026  1.986676  0.006496    1.048535
# 23            0.146920  0.013080    0.291883  1.986676  0.006496    1.204715
# 24            0.146920  0.010385    0.375530  2.556016  0.006322    1.366086
# 25            0.027654  0.010385    0.070684  2.556016  0.006322    1.046303
# 26            0.146920  0.013071    0.267400  1.820038  0.005889    1.164456
# 27            0.048882  0.013071    0.088967  1.820038  0.005889    1.044000
#
#     zhangs_metric
# 0        0.678265
# 1        0.639901
# 2        0.621394
# 3        0.609775
# 4        0.583095
# 5        0.577062
# 6        0.629847
# 7        0.683926
# 8        0.703734
# 9        0.734674
# 10       0.352139
# 11       0.327498
# 12       0.571193
# 13       0.549154
# 14       0.519885
# 15       0.515497
# 16       0.360851
# 17       0.332768
# 18       0.495359
# 19       0.472227
# 20       0.599262
# 21       0.540885
# 22       0.582181
# 23       0.519946
# 24       0.626080
# 25       0.713610
# 26       0.473717
# 27       0.528158

# %%
def eclat(prefix, items, frequent_itemsets, min_support, transactions_len):
    while items:
        item, tidset = items.pop(0)
        itemset = prefix.copy()
        itemset.add(item)
        support = len(tidset) / transactions_len
        if support >= min_support:

            frequent_itemsets.append((itemset, support))
            suffix = []
            for other_item, other_tidset in items:
                new_tidset = tidset & other_tidset  # Intersection of tidsets
                if len(new_tidset) >= min_support * transactions_len:
                    suffix.append((other_item, new_tidset))

            eclat(itemset, suffix, frequent_itemsets, min_support, transactions_len)


def run_eclat(transactions, min_support):

    data = {}
    transactions_len = len(transactions)
    for i, transaction in enumerate(transactions):
        for item in transaction:
            if item not in data:
                data[item] = set()
            data[item].add(i)

    # Convert to list of tuples and sort by frequency
    sorted_items = sorted(data.items(), key=lambda x: len(x[1]), reverse=True)


    frequent_itemsets = []
    eclat(set(), sorted_items, frequent_itemsets, min_support, transactions_len)
    return frequent_itemsets


min_support_threshold = 0.007 
frequent_itemsets = run_eclat(transactions, min_support_threshold)

for itemset in frequent_itemsets:
    if len(itemset[0]) >=2:
        print(f"itemset: {itemset[0]} --> Confidence: {round(itemset[1],3)}")
# Out:
# itemset: {'Banana', 'Organic Strawberries'} --> Confidence: 0.017
# itemset: {'Banana', 'Organic Baby Spinach'} --> Confidence: 0.016
# itemset: {'Banana', 'Organic Hass Avocado'} --> Confidence: 0.01
# itemset: {'Banana', 'Organic Avocado'} --> Confidence: 0.016
# itemset: {'Large Lemon', 'Banana'} --> Confidence: 0.013
# itemset: {'Banana', 'Strawberries'} --> Confidence: 0.013
# itemset: {'Banana', 'Limes'} --> Confidence: 0.01
# itemset: {'Banana', 'Organic Raspberries'} --> Confidence: 0.007
# itemset: {'Banana', 'Organic Whole Milk'} --> Confidence: 0.01
# itemset: {'Banana', 'Cucumber Kirby'} --> Confidence: 0.01
# itemset: {'Organic Fuji Apple', 'Banana'} --> Confidence: 0.01
# itemset: {'Banana', 'Seedless Red Grapes'} --> Confidence: 0.008
# itemset: {'Banana', 'Honeycrisp Apple'} --> Confidence: 0.009
# itemset: {'Organic Strawberries', 'Bag of Organic Bananas'} --> Confidence: 0.02
# itemset: {'Bag of Organic Bananas', 'Organic Baby Spinach'} --> Confidence: 0.016
# itemset: {'Bag of Organic Bananas', 'Organic Hass Avocado'} --> Confidence: 0.019
# itemset: {'Organic Avocado', 'Bag of Organic Bananas'} --> Confidence: 0.007
# itemset: {'Organic Raspberries', 'Bag of Organic Bananas'} --> Confidence: 0.013
# itemset: {'Bag of Organic Bananas', 'Organic Whole Milk'} --> Confidence: 0.008
# itemset: {'Organic Yellow Onion', 'Bag of Organic Bananas'} --> Confidence: 0.008
# itemset: {'Bag of Organic Bananas', 'Organic Zucchini'} --> Confidence: 0.007
# itemset: {'Bag of Organic Bananas', 'Apple Honeycrisp Organic'} --> Confidence: 0.007
# itemset: {'Organic Large Extra Fancy Fuji Apple', 'Bag of Organic Bananas'} --> Confidence: 0.007
# itemset: {'Organic Strawberries', 'Organic Baby Spinach'} --> Confidence: 0.012
# itemset: {'Organic Strawberries', 'Organic Hass Avocado'} --> Confidence: 0.013
# itemset: {'Organic Avocado', 'Organic Strawberries'} --> Confidence: 0.008
# itemset: {'Organic Raspberries', 'Organic Strawberries'} --> Confidence: 0.011
# itemset: {'Organic Strawberries', 'Organic Whole Milk'} --> Confidence: 0.007
# itemset: {'Organic Blueberries', 'Organic Strawberries'} --> Confidence: 0.008
# itemset: {'Organic Baby Spinach', 'Organic Hass Avocado'} --> Confidence: 0.011
# itemset: {'Organic Avocado', 'Organic Baby Spinach'} --> Confidence: 0.01
# itemset: {'Large Lemon', 'Organic Baby Spinach'} --> Confidence: 0.007
# itemset: {'Organic Raspberries', 'Organic Hass Avocado'} --> Confidence: 0.008
# itemset: {'Large Lemon', 'Organic Avocado'} --> Confidence: 0.008
# itemset: {'Large Lemon', 'Limes'} --> Confidence: 0.009
